# %% [markdown]
# <a href="https://colab.research.google.com/github/Viswanathan25/Virtual_internship/blob/main/acc_virtual_intern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#checking the given data
df = pd.read_csv('/content/Content.csv')
df.head(10)
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
# 5           5  cf1e8c1a-23eb-4426-9f58-002fb1b53e91
# 6           6  3f8590c7-6ab2-4973-805a-90cdec355f05
# 7           7  e5490118-90d5-4572-ab1c-1fbc87b8d9ca
# 8           8  0bedca96-fb76-4287-a83c-17330ed39cce
# 9           9  b18cb63f-4c8e-44ee-a47f-541e95191d11
#
#                                 User ID   Type         Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo       technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video             food
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   Content ID  1000 non-null   object
#  2   User ID     1000 non-null   object
#  3   Type        1000 non-null   object
#  4   Category    1000 non-null   object
#  5   URL         801 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
df.shape
# Out:
# (1000, 6)

# %%
#changing datatypes
df['Type'] = df['Type'].astype(str)
df['Category'] = df['Category'].astype(str)

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# Content ID    object
# User ID       object
# Type          object
# Category      object
# URL           object
# dtype: object

# %%
#checking the missing value
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Content ID      0
# User ID         0
# Type            0
# Category        0
# URL           199
# dtype: int64

# %%
#df['URL'] = df['URL'].fillna(0)
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Content ID    0
# User ID       0
# Type          0
# Category      0
# URL           0
# dtype: int64

# %%
#droping the unwanted col
df = df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 994  c54b49c4-b1f2-4641-8595-1cbd19937845
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type        Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
# ...

# %%
df1 = pd.read_csv('/content/Reactions.csv')
df1.head(10)
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5           5  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 6           6  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 7           7  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 8           8  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 9           9  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID        Type             Datetime
# 0                                   NaN         NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2      scared  2021-04-18 05:13:58
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25553 entries, 0 to 25552
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  25553 non-null  int64
#  1   Content ID  25553 non-null  object
#  2   User ID     22534 non-null  object
#  3   Type        24573 non-null  object
#  4   Datetime    25553 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 998.3+ KB

# %%
df1.shape
# Out:
# (25553, 5)

# %%
#changing datatypes
df1['Type'] = df1['Type'].astype(str)
df1['Datetime'] =pd.to_datetime(df1['Datetime'])
df1.dtypes
# Out:
# Unnamed: 0             int64
# Content ID            object
# User ID               object
# Type                  object
# Datetime      datetime64[ns]
# dtype: object

# %%
#checking missing value
df1.isnull().sum()
# Out:
# Unnamed: 0       0
# Content ID       0
# User ID       3019
# Type             0
# Datetime         0
# dtype: int64

# %%
#cleaning missing values
df1 = df1.dropna()

# %%
#droping unwanted data
df1 = df1.drop('Unnamed: 0',axis=1)

# %%
df1
# Out:
#                                  Content ID  \
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25547  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type            Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust 2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike 2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared 2021-04-18 05:13:58
# 4      34e8add9-0206-47fd-a501-037b994650a2     disgust 2021-01-06 19:13:01
# ...

# %%
df3 = pd.read_csv('/content/ReactionTypes.csv')
df3.head(10)
# Out:
#    Unnamed: 0         Type Sentiment  Score
# 0           0        heart  positive     60
# 1           1         want  positive     70
# 2           2      disgust  negative      0
# 3           3         hate  negative      5
# 4           4   interested  positive     30
# 5           5  indifferent   neutral     20
# 6           6         love  positive     65
# 7           7   super love  positive     75
# 8           8      cherish  positive     70
# 9           9        adore  positive     72

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Type       16 non-null     object
#  1   Sentiment  16 non-null     object
#  2   Score      16 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 512.0+ bytes

# %%
df3.shape
# Out:
# (16, 4)

# %%
#checking dypes
df3.dtypes
# Out:
# Unnamed: 0     int64
# Type          object
# Sentiment     object
# Score          int64
# dtype: object

# %%
#checking null values
df3.isnull().sum()
# Out:
# Unnamed: 0    0
# Type          0
# Sentiment     0
# Score         0
# dtype: int64

# %%
#removing unwanted col
df3 = df3.drop('Unnamed: 0',axis=1)

# %%
df3
# Out:
#            Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30
# 5   indifferent   neutral     20
# 6          love  positive     65
# 7    super love  positive     75
# 8       cherish  positive     70
# 9         adore  positive     72
# 10         like  positive     50
# 11      dislike  negative     10
# 12    intrigued  positive     45
# 13      peeking   neutral     35
# 14       scared  negative     15
# 15      worried  negative     12

# %%
#mering cleaned datasets
df = pd.merge(df, df1, on='User ID')
df = pd.merge(df1, df3, on='Type')

# %%
df
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 4      230c4e4d-70c3-461d-b42c-ec09396efb3f
# ...                                     ...
# 22529  435007a5-6261-4d8b-b0a4-55fdc189754b
# 22530  435007a5-6261-4d8b-b0a4-55fdc189754b
# 22531  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 22532  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 22533  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
#
#                                     User ID     Type            Datetime  \
# 0      5d454588-283d-459d-915d-c48a2cb4c27f  disgust 2020-11-07 09:43:50
# 1      34e8add9-0206-47fd-a501-037b994650a2  disgust 2021-01-06 19:13:01
# 2      13c06e7e-833d-47eb-a790-5e09ccfd8d2c  disgust 2021-04-09 02:46:20
# 3      8b49caad-bcc5-43de-bf40-34a66ff8805c  disgust 2021-03-28 21:15:26
# ...

# %%
df.to_csv('Final-datasets.csv',index=False)
